# %% [markdown]
# # DO something to not run code for 230 asset

# %%
import mysql.connector
from nsepython import option_chain, fnolist
from datetime import datetime
import time

# MySQL Database Credentials
DB_CONFIG = {
    'host': 'localhost',
    'user': 'root',
    'password': 'Solar@345',
    'database': 'option_data'
}

# Connect to MySQL Database
def connect_to_db():
    try:
        conn = mysql.connector.connect(**DB_CONFIG)
        return conn
    except mysql.connector.Error as err:
        print(f"Database connection error: {err}")
        raise

# Function to insert or get asset ID
def get_asset_id(cursor, asset_name):
    cursor.execute("""
        INSERT INTO assets (asset_name) VALUES (%s) 
        ON DUPLICATE KEY UPDATE id=LAST_INSERT_ID(id)
    """, (asset_name,))
    return cursor.lastrowid

# Function to insert or get expiry ID
def get_expiry_id(cursor, asset_id, expiry_date):
    formatted_date = datetime.strptime(expiry_date, "%d-%b-%Y").strftime("%Y-%m-%d")
    cursor.execute("""
        INSERT INTO expiries (asset_id, expiry_date) VALUES (%s, %s)
        ON DUPLICATE KEY UPDATE id=LAST_INSERT_ID(id)
    """, (asset_id, formatted_date))
    return cursor.lastrowid

# Function to insert/update option data
def update_option_data(cursor, asset_id, expiry_id, strike_price, option_type, data):
    identifier = data["identifier"]
    cursor.execute("""
        INSERT INTO option_chain (asset_id, expiry_id, strike_price, option_type, identifier, open_interest, change_in_oi, 
                                  total_traded_volume, implied_volatility, last_price, bid_qty, bid_price, ask_qty, ask_price, 
                                  total_buy_qty, total_sell_qty) 
        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)
        ON DUPLICATE KEY UPDATE 
            open_interest = VALUES(open_interest),
            change_in_oi = VALUES(change_in_oi),
            total_traded_volume = VALUES(total_traded_volume),
            implied_volatility = VALUES(implied_volatility),
            last_price = VALUES(last_price),
            bid_qty = VALUES(bid_qty),
            bid_price = VALUES(bid_price),
            ask_qty = VALUES(ask_qty),
            ask_price = VALUES(ask_price),
            total_buy_qty = VALUES(total_buy_qty),
            total_sell_qty = VALUES(total_sell_qty),
            last_updated = CURRENT_TIMESTAMP
    """, (
        asset_id, expiry_id, strike_price, option_type, identifier,
        data["openInterest"], data["changeinOpenInterest"], data["totalTradedVolume"],
        data["impliedVolatility"], data["lastPrice"], data["bidQty"], data["bidprice"],
        data["askQty"], data["askPrice"], data["totalBuyQuantity"], data["totalSellQuantity"]
    ))

# Fetch and store option chain data
def fetch_and_store(asset_name):
    conn = connect_to_db()
    cursor = conn.cursor()

    try:
        print(f"Fetching data for {asset_name}...")
        chain = option_chain(asset_name)

        asset_id = get_asset_id(cursor, asset_name)
        expiry_ids = {exp: get_expiry_id(cursor, asset_id, exp) for exp in chain['records']['expiryDates']}

        for entry in chain['records']['data']:
            strike_price = entry['strikePrice']
            expiry_date = entry['expiryDate']
            expiry_id = expiry_ids.get(expiry_date)

            for option_type in ["CE", "PE"]:
                if option_type in entry:
                    update_option_data(cursor, asset_id, expiry_id, strike_price, option_type, entry[option_type])

        conn.commit()
        print(f"Updated data for {asset_name}")

    except Exception as e:
        conn.rollback()
        print(f"Error processing {asset_name}: {e}")

    finally:
        cursor.close()
        conn.close()

# Function to copy data to a buffer table
def copy_to_buffer(buffer_table, asset_id):
    conn = connect_to_db()
    cursor = conn.cursor()

    try:
        cursor.execute(f"DELETE FROM {buffer_table}")  # Clear old data

        cursor.execute(f"""
            INSERT INTO {buffer_table} 
            SELECT * FROM option_chain WHERE asset_id = %s
        """, (asset_id,))

        conn.commit()
        print(f"Copied data for asset {asset_id} to {buffer_table}")

    except Exception as e:
        conn.rollback()
        print(f"Error copying to {buffer_table}: {e}")

    finally:
        cursor.close()
        conn.close()

# Assign buffer tables dynamically
def update_comparison_buffers(selected_assets):
    if len(selected_assets) > 6:
        print("Error: You can only compare up to 6 assets.")
        return
    
    conn = connect_to_db()
    cursor = conn.cursor()

    buffer_tables = [f"buffer_{i}" for i in range(1, 7)]  # Buffer table names

    try:
        for i, asset_name in enumerate(selected_assets):
            cursor.execute("SELECT id FROM assets WHERE asset_name = %s", (asset_name,))
            asset = cursor.fetchone()

            if asset:
                asset_id = asset[0]
                copy_to_buffer(buffer_tables[i], asset_id)
            else:
                print(f"Asset {asset_name} not found in database.")

    except Exception as e:
        print(f"Error updating comparison buffers: {e}")

    finally:
        cursor.close()
        conn.close()

# Main function to fetch all 230 assets initially
def main():
    assets = fnolist()
    for asset in assets:
        fetch_and_store(asset)

# Live update function
def live_update(selected_assets):
    while True:
        # Always update NIFTY
        fetch_and_store("NIFTY")

        # Update only selected assets in buffers
        for asset in selected_assets:
            fetch_and_store(asset)

        time.sleep(30)

if __name__ == "__main__":
    main()  # Load all assets initially
    selected_assets = ["NIFTY"]  # Default selection
    live_update(selected_assets)  # Start updating selected assets
# Out:
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTYIT...
# Error processing NIFTYIT: 'records'
# Fetching data for BANKNIFTY...
# Updated data for BANKNIFTY
# Fetching data for CHAMBLFERT...
# Updated data for CHAMBLFERT
# Fetching data for TATASTEEL...
# Updated data for TATASTEEL
# Fetching data for JINDALSTEL...
# Updated data for JINDALSTEL
# Fetching data for BHARTIARTL...
# Updated data for BHARTIARTL
# Fetching data for JSWSTEEL...
# Updated data for JSWSTEEL
# Fetching data for DIXON...
# Updated data for DIXON
# Fetching data for TORNTPHARM...
# Updated data for TORNTPHARM
# Fetching data for LODHA...
# Updated data for LODHA
# Fetching data for TRENT...
# Updated data for TRENT
# Fetching data for GLENMARK...
# Updated data for GLENMARK
# Fetching data for VEDL...
# Updated data for VEDL
# Fetching data for FEDERALBNK...
# Updated data for FEDERALBNK
# Fetching data for BSE...
# Updated data for BSE
# Fetching data for ABBOTINDIA...
# Updated data for ABBOTINDIA
# Fetching data for VOLTAS...
# Updated data for VOLTAS
# Fetching data for APOLLOTYRE...
# Updated data for APOLLOTYRE
# Fetching data for HINDALCO...
# Updated data for HINDALCO
# Fetching data for NMDC...
# Updated data for NMDC
# Fetching data for IDEA...
# Updated data for IDEA
# Fetching data for TORNTPOWER...
# Updated data for TORNTPOWER
# Fetching data for KOTAKBANK...
# Updated data for KOTAKBANK
# Fetching data for SAIL...
# Updated data for SAIL
# Fetching data for ZOMATO...
# Updated data for ZOMATO
# Fetching data for NATIONALUM...
# Updated data for NATIONALUM
# Fetching data for INDUSTOWER...
# Updated data for INDUSTOWER
# Fetching data for SHREECEM...
# Updated data for SHREECEM
# Fetching data for OFSS...
# Updated data for OFSS
# Fetching data for PETRONET...
# Updated data for PETRONET
# Fetching data for M&M...
# Updated data for M&M
# Fetching data for BAJAJ-AUTO...
# Updated data for BAJAJ-AUTO
# Fetching data for RECLTD...
# Updated data for RECLTD
# Fetching data for PAYTM...
# Updated data for PAYTM
# Fetching data for MPHASIS...
# Updated data for MPHASIS
# Fetching data for MANAPPURAM...
# Updated data for MANAPPURAM
# Fetching data for CYIENT...
# Updated data for CYIENT
# Fetching data for ULTRACEMCO...
# Updated data for ULTRACEMCO
# Fetching data for HINDCOPPER...
# Updated data for HINDCOPPER
# Fetching data for SUPREMEIND...
# Updated data for SUPREMEIND
# Fetching data for NTPC...
# Updated data for NTPC
# Fetching data for MAXHEALTH...
# Updated data for MAXHEALTH
# Fetching data for MGL...
# Updated data for MGL
# Fetching data for HAL...
# Updated data for HAL
# Fetching data for HEROMOTOCO...
# Updated data for HEROMOTOCO
# Fetching data for TECHM...
# Updated data for TECHM
# Fetching data for PHOENIXLTD...
# Updated data for PHOENIXLTD
# Fetching data for MOTHERSON...
# Updated data for MOTHERSON
# Fetching data for ADANIENT...
# Updated data for ADANIENT
# Fetching data for LTTS...
# Updated data for LTTS
# Fetching data for PFC...
# Updated data for PFC
# Fetching data for ASHOKLEY...
# Updated data for ASHOKLEY
# Fetching data for INDUSINDBK...
# Updated data for INDUSINDBK
# Fetching data for IDFCFIRSTB...
# Updated data for IDFCFIRSTB
# Fetching data for TATACOMM...
# Updated data for TATACOMM
# Fetching data for POLICYBZR...
# Updated data for POLICYBZR
# Fetching data for BERGEPAINT...
# Updated data for BERGEPAINT
# Fetching data for EICHERMOT...
# Updated data for EICHERMOT
# Fetching data for BSOFT...
# Updated data for BSOFT
# Fetching data for CUB...
# Updated data for CUB
# Fetching data for OBEROIRLTY...
# Updated data for OBEROIRLTY
# Fetching data for AUBANK...
# Updated data for AUBANK
# Fetching data for HDFCLIFE...
# Updated data for HDFCLIFE
# Fetching data for CROMPTON...
# Updated data for CROMPTON
# Fetching data for HFCL...
# Updated data for HFCL
# Fetching data for KPITTECH...
# Updated data for KPITTECH
# Fetching data for UNITDSPR...
# Updated data for UNITDSPR
# Fetching data for LUPIN...
# Updated data for LUPIN
# Fetching data for BAJAJFINSV...
# Updated data for BAJAJFINSV
# Fetching data for CANFINHOME...
# Updated data for CANFINHOME
# Fetching data for LAURUSLABS...
# Updated data for LAURUSLABS
# Fetching data for BPCL...
# Updated data for BPCL
# Fetching data for TITAN...
# Updated data for TITAN
# Fetching data for SBICARD...
# Updated data for SBICARD
# Fetching data for HAVELLS...
# Updated data for HAVELLS
# Fetching data for CDSL...
# Updated data for CDSL
# Fetching data for APLAPOLLO...
# Updated data for APLAPOLLO
# Fetching data for MUTHOOTFIN...
# Updated data for MUTHOOTFIN
# Fetching data for INDHOTEL...
# Updated data for INDHOTEL
# Fetching data for PERSISTENT...
# Updated data for PERSISTENT
# Fetching data for TATAPOWER...
# Updated data for TATAPOWER
# Fetching data for BHARATFORG...
# Updated data for BHARATFORG
# Fetching data for ASIANPAINT...
# Updated data for ASIANPAINT
# Fetching data for TVSMOTOR...
# Updated data for TVSMOTOR
# Fetching data for RBLBANK...
# Updated data for RBLBANK
# Fetching data for GRANULES...
# Updated data for GRANULES
# Fetching data for DRREDDY...
# Updated data for DRREDDY
# Fetching data for RAMCOCEM...
# Updated data for RAMCOCEM
# Fetching data for SBILIFE...
# Updated data for SBILIFE
# Fetching data for DIVISLAB...
# Updated data for DIVISLAB
# Fetching data for JSL...
# Updated data for JSL
# Fetching data for ACC...
# Updated data for ACC
# Fetching data for GNFC...
# Updated data for GNFC
# Fetching data for HUDCO...
# Updated data for HUDCO
# Fetching data for SUNPHARMA...
# Updated data for SUNPHARMA
# Fetching data for LALPATHLAB...
# Updated data for LALPATHLAB
# Fetching data for MFSL...
# Updated data for MFSL
# Fetching data for CAMS...
# Updated data for CAMS
# Fetching data for LICHSGFIN...
# Updated data for LICHSGFIN
# Fetching data for M&MFIN...
# Updated data for M&MFIN
# Fetching data for DABUR...
# Updated data for DABUR
# Fetching data for POLYCAB...
# Updated data for POLYCAB
# Fetching data for ADANIENSOL...
# Updated data for ADANIENSOL
# Fetching data for CGPOWER...
# Updated data for CGPOWER
# Fetching data for ABCAPITAL...
# Updated data for ABCAPITAL
# Fetching data for AXISBANK...
# Updated data for AXISBANK
# Fetching data for HCLTECH...
# Updated data for HCLTECH
# Fetching data for BANDHANBNK...
# Updated data for BANDHANBNK
# Fetching data for DELHIVERY...
# Updated data for DELHIVERY
# Fetching data for DMART...
# Updated data for DMART
# Fetching data for ICICIPRULI...
# Updated data for ICICIPRULI
# Fetching data for AUROPHARMA...
# Updated data for AUROPHARMA
# Fetching data for LTIM...
# Updated data for LTIM
# Fetching data for GMRAIRPORT...
# Updated data for GMRAIRPORT
# Fetching data for CIPLA...
# Updated data for CIPLA
# Fetching data for ICICIGI...
# Updated data for ICICIGI
# Fetching data for TATAELXSI...
# Updated data for TATAELXSI
# Fetching data for ABB...
# Updated data for ABB
# Fetching data for COFORGE...
# Updated data for COFORGE
# Fetching data for ESCORTS...
# Updated data for ESCORTS
# Fetching data for NYKAA...
# Updated data for NYKAA
# Fetching data for NHPC...
# Updated data for NHPC
# Fetching data for OIL...
# Updated data for OIL
# Fetching data for JKCEMENT...
# Updated data for JKCEMENT
# Fetching data for COALINDIA...
# Updated data for COALINDIA
# Fetching data for AMBUJACEM...
# Updated data for AMBUJACEM
# Fetching data for BOSCHLTD...
# Updated data for BOSCHLTD
# Fetching data for TATACONSUM...
# Updated data for TATACONSUM
# Fetching data for SOLARINDS...
# Updated data for SOLARINDS
# Fetching data for WIPRO...
# Updated data for WIPRO
# Fetching data for HINDPETRO...
# Updated data for HINDPETRO
# Fetching data for MARUTI...
# Updated data for MARUTI
# Fetching data for IEX...
# Updated data for IEX
# Fetching data for HINDUNILVR...
# Updated data for HINDUNILVR
# Fetching data for KEI...
# Updated data for KEI
# Fetching data for BAJFINANCE...
# Updated data for BAJFINANCE
# Fetching data for INDIAMART...
# Updated data for INDIAMART
# Fetching data for SYNGENE...
# Updated data for SYNGENE
# Fetching data for JIOFIN...
# Updated data for JIOFIN
# Fetching data for COROMANDEL...
# Updated data for COROMANDEL
# Fetching data for TATAMOTORS...
# Updated data for TATAMOTORS
# Fetching data for MCX...
# Updated data for MCX
# Fetching data for HDFCAMC...
# Updated data for HDFCAMC
# Fetching data for PNB...
# Updated data for PNB
# Fetching data for ASTRAL...
# Updated data for ASTRAL
# Fetching data for CHOLAFIN...
# Updated data for CHOLAFIN
# Fetching data for UPL...
# Updated data for UPL
# Fetching data for TATACHEM...
# Updated data for TATACHEM
# Fetching data for GRASIM...
# Updated data for GRASIM
# Fetching data for NESTLEIND...
# Updated data for NESTLEIND
# Fetching data for EXIDEIND...
# Updated data for EXIDEIND
# Fetching data for SONACOMS...
# Updated data for SONACOMS
# Fetching data for YESBANK...
# Updated data for YESBANK
# Fetching data for NAVINFLUOR...
# Updated data for NAVINFLUOR
# Fetching data for DALBHARAT...
# Updated data for DALBHARAT
# Fetching data for SRF...
# Updated data for SRF
# Fetching data for HDFCBANK...
# Updated data for HDFCBANK
# Fetching data for LT...
# Updated data for LT
# Fetching data for IPCALAB...
# Updated data for IPCALAB
# Fetching data for JUBLFOOD...
# Updated data for JUBLFOOD
# Fetching data for CONCOR...
# Updated data for CONCOR
# Fetching data for IOC...
# Updated data for IOC
# Fetching data for PIDILITIND...
# Updated data for PIDILITIND
# Fetching data for INFY...
# Updated data for INFY
# Fetching data for ADANIGREEN...
# Updated data for ADANIGREEN
# Fetching data for METROPOLIS...
# Updated data for METROPOLIS
# Fetching data for BEL...
# Updated data for BEL
# Fetching data for CANBK...
# Updated data for CANBK
# Fetching data for INDIGO...
# Updated data for INDIGO
# Fetching data for ATGL...
# Updated data for ATGL
# Fetching data for POWERGRID...
# Updated data for POWERGRID
# Fetching data for KALYANKJIL...
# Updated data for KALYANKJIL
# Fetching data for SHRIRAMFIN...
# Updated data for SHRIRAMFIN
# Fetching data for APOLLOHOSP...
# Updated data for APOLLOHOSP
# Fetching data for GODREJCP...
# Updated data for GODREJCP
# Fetching data for INDIANB...
# Updated data for INDIANB
# Fetching data for UNIONBANK...
# Updated data for UNIONBANK
# Fetching data for MRF...
# Updated data for MRF
# Fetching data for DLF...
# Updated data for DLF
# Fetching data for ABFRL...
# Updated data for ABFRL
# Fetching data for ANGELONE...
# Updated data for ANGELONE
# Fetching data for POONAWALLA...
# Updated data for POONAWALLA
# Fetching data for BANKINDIA...
# Updated data for BANKINDIA
# Fetching data for ATUL...
# Updated data for ATUL
# Fetching data for RELIANCE...
# Updated data for RELIANCE
# Fetching data for DEEPAKNTR...
# Updated data for DEEPAKNTR
# Fetching data for BHEL...
# Updated data for BHEL
# Fetching data for ICICIBANK...
# Updated data for ICICIBANK
# Fetching data for TCS...
# Updated data for TCS
# Fetching data for AARTIIND...
# Updated data for AARTIIND
# Fetching data for IRCTC...
# Updated data for IRCTC
# Fetching data for UBL...
# Updated data for UBL
# Fetching data for LTF...
# Updated data for LTF
# Fetching data for IGL...
# Updated data for IGL
# Fetching data for BALKRISIND...
# Updated data for BALKRISIND
# Fetching data for ZYDUSLIFE...
# Updated data for ZYDUSLIFE
# Fetching data for IRB...
# Updated data for IRB
# Fetching data for BANKBARODA...
# Updated data for BANKBARODA
# Fetching data for PEL...
# Updated data for PEL
# Fetching data for ADANIPORTS...
# Updated data for ADANIPORTS
# Fetching data for SUNTV...
# Updated data for SUNTV
# Fetching data for SJVN...
# Updated data for SJVN
# Fetching data for BATAINDIA...
# Updated data for BATAINDIA
# Fetching data for BRITANNIA...
# Updated data for BRITANNIA
# Fetching data for JSWENERGY...
# Updated data for JSWENERGY
# Fetching data for TIINDIA...
# Updated data for TIINDIA
# Fetching data for GUJGASLTD...
# Updated data for GUJGASLTD
# Fetching data for MARICO...
# Updated data for MARICO
# Fetching data for ALKEM...
# Updated data for ALKEM
# Fetching data for PRESTIGE...
# Updated data for PRESTIGE
# Fetching data for NAUKRI...
# Updated data for NAUKRI
# Fetching data for IRFC...
# Updated data for IRFC
# Fetching data for SBIN...
# Updated data for SBIN
# Fetching data for LICI...
# Updated data for LICI
# Fetching data for COLPAL...
# Updated data for COLPAL
# Fetching data for SIEMENS...
# Updated data for SIEMENS
# Fetching data for NBCC...
# Updated data for NBCC
# Fetching data for CESC...
# Updated data for CESC
# Fetching data for GODREJPROP...
# Updated data for GODREJPROP
# Fetching data for ITC...
# Updated data for ITC
# Fetching data for VBL...
# Updated data for VBL
# Fetching data for PAGEIND...
# Updated data for PAGEIND
# Fetching data for BIOCON...
# Updated data for BIOCON
# Fetching data for PVRINOX...
# Updated data for PVRINOX
# Fetching data for ONGC...
# Updated data for ONGC
# Fetching data for PIIND...
# Updated data for PIIND
# Fetching data for CUMMINSIND...
# Updated data for CUMMINSIND
# Fetching data for GAIL...
# Updated data for GAIL
# Fetching data for NCC...
# Updated data for NCC
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# Fetching data for NIFTY...
# Updated data for NIFTY
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 174
#     172 main()  # Load all assets initially
#     173 selected_assets = ["NIFTY"]  # Default selection
# --> 174 live_update(selected_assets)  # Start updating selected assets
#
# Cell In[1], line 169, in live_update(selected_assets)
#     166 for asset in selected_assets:
#     167     fetch_and_store(asset)
# --> 169 time.sleep(30)
#
# KeyboardInterrupt:
